# %% [markdown]
# # Food Demand Forecasting

# %% [markdown]
# ## Problem Statement
# Your client is a meal delivery company which operates in multiple cities. They have various fulfillment centers in these cities for dispatching meal orders to their customers. The client wants you to help these centers with demand forecasting for upcoming weeks so that these centers will plan the stock of raw materials accordingly.
#
# The replenishment of majority of raw materials is done on weekly basis and since the raw material is perishable, the procurement planning is of utmost importance. Secondly, staffing of the centers is also one area wherein accurate demand forecasts are really helpful. Given the following information, the task is to predict the demand for the next 10 weeks (Weeks: 146-155) for the center-meal combinations in the test set:
#
# - Historical data of demand for a product-center combination (Weeks: 1 to 145)
# - Product(Meal) features such as category, sub-category, current price and discount
# - Information for fulfillment center like center area, city information etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv('/content/train.csv')
df_test = pd.read_csv('/content/test_QoiMO9B.csv')
df_fulfilment_center_info = pd.read_csv('/content/fulfilment_center_info.csv')
df_meal_info = pd.read_csv('meal_info.csv')

# %%
df_train.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  int64
#  3   meal_id                456548 non-null  int64
#  4   checkout_price         456548 non-null  float64
#  5   base_price             456548 non-null  float64
#  6   emailer_for_promotion  456548 non-null  int64
#  7   homepage_featured      456548 non-null  int64
#  8   num_orders             456548 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 31.3 MB

# %%
df_train.describe()
# Out:
#                  id           week      center_id        meal_id  \
# count  4.565480e+05  456548.000000  456548.000000  456548.000000
# mean   1.250096e+06      74.768771      82.105796    2024.337458
# std    1.443548e+05      41.524956      45.975046     547.420920
# min    1.000000e+06       1.000000      10.000000    1062.000000
# 25%    1.124999e+06      39.000000      43.000000    1558.000000
# 50%    1.250184e+06      76.000000      76.000000    1993.000000
# 75%    1.375140e+06     111.000000     110.000000    2539.000000
# max    1.499999e+06     145.000000     186.000000    2956.000000
#
#        checkout_price     base_price  emailer_for_promotion  \
# count   456548.000000  456548.000000          456548.000000
# mean       332.238933     354.156627               0.081152
# std        152.939723     160.715914               0.273069
# min          2.970000      55.350000               0.000000
# 25%        228.950000     243.500000               0.000000
# ...

# %%
df_train.isnull().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# dtype: int64

# %%
df_fulfilment_center_info.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
df_fulfilment_center_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   center_id    77 non-null     int64
#  1   city_code    77 non-null     int64
#  2   region_code  77 non-null     int64
#  3   center_type  77 non-null     object
#  4   op_area      77 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 3.1+ KB

# %%
df_fulfilment_center_info.describe()
# Out:
#         center_id   city_code  region_code    op_area
# count   77.000000   77.000000    77.000000  77.000000
# mean    83.142857  600.662338    56.493506   3.985714
# std     46.090219   66.720274    18.126473   1.106406
# min     10.000000  456.000000    23.000000   0.900000
# 25%     50.000000  553.000000    34.000000   3.500000
# 50%     77.000000  596.000000    56.000000   3.900000
# 75%    110.000000  651.000000    77.000000   4.400000
# max    186.000000  713.000000    93.000000   7.000000

# %%
df_fulfilment_center_info.isnull().sum()
# Out:
# center_id      0
# city_code      0
# region_code    0
# center_type    0
# op_area        0
# dtype: int64

# %%
df_meal_info.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
# Merging the train dataset

# %%
df_merge1 = df_train.merge(df_meal_info, how='left', on='meal_id')
df_merge1
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# ...

# %%
df1_train =df_merge1.merge(df_fulfilment_center_info,how='left', on='center_id')
df1_train
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# ...

# %%
#merging the test data

# %%
df_merge2 = df_test.merge(df_meal_info, how='left', on='meal_id')
df_merge2
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   146         55     1885          158.11      159.11
# 1      1127204   146         55     1993          160.11      159.11
# 2      1212707   146         55     2539          157.14      159.14
# 3      1082698   146         55     2631          162.02      162.02
# 4      1400926   146         55     1248          163.93      163.93
# ...        ...   ...        ...      ...             ...         ...
# 32568  1250239   155         61     1543          482.09      484.09
# 32569  1039516   155         61     2304          483.09      483.09
# 32570  1158107   155         61     2664          322.07      323.07
# 32571  1444235   155         61     2569          322.07      323.07
# 32572  1291286   155         61     2490          276.45      276.45
#
#        emailer_for_promotion  homepage_featured   category  cuisine
# 0                          0                  0  Beverages     Thai
# ...

# %%
df1_test =df_merge2.merge(df_fulfilment_center_info, how='left', on='center_id')
df1_test
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   146         55     1885          158.11      159.11
# 1      1127204   146         55     1993          160.11      159.11
# 2      1212707   146         55     2539          157.14      159.14
# 3      1082698   146         55     2631          162.02      162.02
# 4      1400926   146         55     1248          163.93      163.93
# ...        ...   ...        ...      ...             ...         ...
# 32568  1250239   155         61     1543          482.09      484.09
# 32569  1039516   155         61     2304          483.09      483.09
# 32570  1158107   155         61     2664          322.07      323.07
# 32571  1444235   155         61     2569          322.07      323.07
# 32572  1291286   155         61     2490          276.45      276.45
#
#        emailer_for_promotion  homepage_featured   category  cuisine  \
# 0                          0                  0  Beverages     Thai
# ...

# %%
# After merging

# %%
df1_train.shape
# Out:
# (456548, 15)

# %%
df1_train.size
# Out:
# 6848220

# %%
df1_train.describe().T
# Out:
#                           count          mean            std         min  \
# id                     456548.0  1.250096e+06  144354.822378  1000000.00
# week                   456548.0  7.476877e+01      41.524956        1.00
# center_id              456548.0  8.210580e+01      45.975046       10.00
# meal_id                456548.0  2.024337e+03     547.420920     1062.00
# checkout_price         456548.0  3.322389e+02     152.939723        2.97
# base_price             456548.0  3.541566e+02     160.715914       55.35
# emailer_for_promotion  456548.0  8.115247e-02       0.273069        0.00
# homepage_featured      456548.0  1.091999e-01       0.311890        0.00
# num_orders             456548.0  2.618728e+02     395.922798       13.00
# city_code              456548.0  6.015534e+02      66.195914      456.00
# region_code            456548.0  5.661457e+01      17.641306       23.00
# op_area                456548.0  4.083590e+00       1.091686        0.90
#
# ...

# %%
df1_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  int64
#  3   meal_id                456548 non-null  int64
#  4   checkout_price         456548 non-null  float64
#  5   base_price             456548 non-null  float64
#  6   emailer_for_promotion  456548 non-null  int64
#  7   homepage_featured      456548 non-null  int64
#  8   num_orders             456548 non-null  int64
#  9   category               456548 non-null  object
#  10  cuisine                456548 non-null  object
#  11  city_code              456548 non-null  int64
#  12  region_code            456548 non-null  int64
#  13  center_type            456548 non-null  object
# ...

# %%
#checking for duplicates
df1_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking for duplicate columns
df1_train.columns.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Duplicates not found

# %%
# checking for missing values
df1_train.isna().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# category                 0
# cuisine                  0
# city_code                0
# region_code              0
# center_type              0
# op_area                  0
# dtype: int64

# %%
# outlier handling

# %%
# Seperating numerical and categorical columns
numerical_df = df1_train.select_dtypes(include="number")
categorical_df = df1_train.select_dtypes(include="object_")

# %%
numerical_cols = numerical_df.columns.tolist()
categorical_cols = categorical_df.columns.tolist()
print("Numerical Columns are {}".format(numerical_cols))
print("Categorical Columns are {}".format(categorical_cols))
# Out:
# Numerical Columns are ['id', 'week', 'center_id', 'meal_id', 'checkout_price', 'base_price', 'emailer_for_promotion', 'homepage_featured', 'num_orders', 'city_code', 'region_code', 'op_area']
# Categorical Columns are ['category', 'cuisine', 'center_type']

# %%
numerical_df.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                      0                  0         177        647
# 1                      0                  0         270        647
# 2                      0                  0         189        647
# 3                      0                  0          54        647
# 4                      0                  0          40        647
#
#    region_code  op_area
# 0           56      2.0
# 1           56      2.0
# 2           56      2.0
# 3           56      2.0
# 4           56      2.0

# %%
categorical_df.head()
# Out:
#     category cuisine center_type
# 0  Beverages    Thai      TYPE_C
# 1  Beverages    Thai      TYPE_C
# 2  Beverages    Thai      TYPE_C
# 3  Beverages  Indian      TYPE_C
# 4  Beverages  Indian      TYPE_C

# %%
plt.figure(figsize=(10,6))
numerical_df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
#outliers handling using iqr

# %%
def remove_outliers(df, column_name):
    q1 = df[column_name].quantile(0.25)
    q3 = df[column_name].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5 * iqr
    lower_bound = q1 - 1.5 * iqr
    df[column_name] = df[column_name].clip(upper=upper_bound)
    df[column_name] = df[column_name].clip(lower=lower_bound)
    return df[column_name]

# %%
for col in numerical_cols:
 numerical_df[col] = remove_outliers(numerical_df, col)

# %%
plt.figure(figsize=(10,6))
numerical_df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
# Seperating numerical and categorical attributes
numerical_attr = df1_train[["checkout_price","base_price","num_orders","op_area"]]
categorical_attr = df1_train[["id","week","center_id","meal_id","emailer_for_promotion","homepage_featured","city_code","region_code","category","cuisine","center_type"]]

# %%
# Feature encoding

# %%
categorical_df.describe()
# Out:
#          category  cuisine center_type
# count      456548   456548      456548
# unique         14        4           3
# top     Beverages  Italian      TYPE_A
# freq       127890   122925      262881

# %%
# Frequency encoding for category column on training data

# %%
category_frequency = df1_train["category"].value_counts(normalize= True)
df1_train['category_encoded'] = df1_train['category'].map(category_frequency)
df1_train
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# ...

# %%
df1_train = df1_train.drop('category',axis= 1)

# %%
# Frequency encoding for category column on testing data

# %%
category_frequency1 = df1_test["category"].value_counts(normalize= True)
df1_test['category_encoded'] = df1_test['category'].map(category_frequency1)
df1_test
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   146         55     1885          158.11      159.11
# 1      1127204   146         55     1993          160.11      159.11
# 2      1212707   146         55     2539          157.14      159.14
# 3      1082698   146         55     2631          162.02      162.02
# 4      1400926   146         55     1248          163.93      163.93
# ...        ...   ...        ...      ...             ...         ...
# 32568  1250239   155         61     1543          482.09      484.09
# 32569  1039516   155         61     2304          483.09      483.09
# 32570  1158107   155         61     2664          322.07      323.07
# 32571  1444235   155         61     2569          322.07      323.07
# 32572  1291286   155         61     2490          276.45      276.45
#
#        emailer_for_promotion  homepage_featured   category  cuisine  \
# 0                          0                  0  Beverages     Thai
# ...

# %%
df1_test = df1_test.drop('category',axis= 1)

# %%
categorical_df["cuisine"].value_counts()
# Out:
# cuisine
# Italian        122925
# Thai           118216
# Indian         112612
# Continental    102795
# Name: count, dtype: int64

# %%
# Onehot Encoding for cuisine type in training data
df1_train = pd.get_dummies(df1_train, columns=['cuisine'],dtype= int, prefix='cuisine', drop_first=True)
df1_train.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                      0                  0         177        647
# 1                      0                  0         270        647
# 2                      0                  0         189        647
# 3                      0                  0          54        647
# 4                      0                  0          40        647
#
#    region_code center_type  op_area  category_encoded  cuisine_Indian  \
# 0           56      TYPE_C      2.0          0.280124               0
# ...

# %%
# Onehot Encoding for cuisine type in testing data
df1_test = pd.get_dummies(df1_test, columns=['cuisine'],dtype= int, prefix='cuisine', drop_first=True)
df1_test.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1028232   146         55     1885          158.11      159.11
# 1  1127204   146         55     1993          160.11      159.11
# 2  1212707   146         55     2539          157.14      159.14
# 3  1082698   146         55     2631          162.02      162.02
# 4  1400926   146         55     1248          163.93      163.93
#
#    emailer_for_promotion  homepage_featured  city_code  region_code  \
# 0                      0                  0        647           56
# 1                      0                  0        647           56
# 2                      0                  0        647           56
# 3                      0                  0        647           56
# 4                      0                  0        647           56
#
#   center_type  op_area  category_encoded  cuisine_Indian  cuisine_Italian  \
# 0      TYPE_C      2.0          0.272956               0                0
# ...

# %%
categorical_df["center_type"].value_counts()
# Out:
# center_type
# TYPE_A    262881
# TYPE_C     99593
# TYPE_B     94074
# Name: count, dtype: int64

# %%
# Onehot Encoding for center_type for training
df1_train = pd.get_dummies(df1_train, columns=['center_type'],dtype= int, prefix='Center', drop_first=True)
df1_train.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                      0                  0         177        647
# 1                      0                  0         270        647
# 2                      0                  0         189        647
# 3                      0                  0          54        647
# 4                      0                  0          40        647
#
#    region_code  op_area  category_encoded  cuisine_Indian  cuisine_Italian  \
# 0           56      2.0          0.280124               0                0
# ...

# %%
# Onehot Encoding for center_type for testing
df1_test = pd.get_dummies(df1_test, columns=['center_type'],dtype= int, prefix='Center', drop_first=True)
df1_test.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1028232   146         55     1885          158.11      159.11
# 1  1127204   146         55     1993          160.11      159.11
# 2  1212707   146         55     2539          157.14      159.14
# 3  1082698   146         55     2631          162.02      162.02
# 4  1400926   146         55     1248          163.93      163.93
#
#    emailer_for_promotion  homepage_featured  city_code  region_code  op_area  \
# 0                      0                  0        647           56      2.0
# 1                      0                  0        647           56      2.0
# 2                      0                  0        647           56      2.0
# 3                      0                  0        647           56      2.0
# 4                      0                  0        647           56      2.0
#
#    category_encoded  cuisine_Indian  cuisine_Italian  cuisine_Thai  \
# ...

# %%
#Feature Scaling

# %%
#Min max scaling in train data
min_scaler = MinMaxScaler()
numerical_colms1 = ['checkout_price','base_price','op_area',"week"]
df1_train[numerical_colms1] = min_scaler.fit_transform(df1_train[numerical_colms1])
df1_train
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560   0.0         55     1885        0.155056    0.119543
# 1       1466964   0.0         55     1993        0.155056    0.099245
# 2       1346989   0.0         55     2539        0.152774    0.099282
# 3       1338232   0.0         55     2139        0.389818    0.471292
# 4       1448490   0.0         55     2631        0.278617    0.230787
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   1.0         61     1543        0.557303    0.528708
# 456544  1062036   1.0         61     2304        0.554987    0.526242
# 456545  1110849   1.0         61     2664        0.271875    0.327677
# 456546  1147725   1.0         61     2569        0.278617    0.318145
# 456547  1361984   1.0         61     2490        0.334831    0.289400
#
#         emailer_for_promotion  homepage_featured  num_orders  city_code  \
# ...

# %%
#Min max scaling in test data
min_scaler1 = MinMaxScaler()
numerical_colms2 = ['checkout_price','base_price','op_area',"week"]
df1_test[numerical_colms1] = min_scaler1.fit_transform(df1_test[numerical_colms1])
df1_test
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   0.0         55     1885        0.086266    0.068274
# 1      1127204   0.0         55     1993        0.088178    0.068274
# 2      1212707   0.0         55     2539        0.085338    0.068303
# 3      1082698   0.0         55     2631        0.090005    0.071117
# 4      1400926   0.0         55     1248        0.091831    0.072984
# ...        ...   ...        ...      ...             ...         ...
# 32568  1250239   1.0         61     1543        0.396081    0.385829
# 32569  1039516   1.0         61     2304        0.397037    0.384852
# 32570  1158107   1.0         61     2664        0.243057    0.228488
# 32571  1444235   1.0         61     2569        0.243057    0.228488
# 32572  1291286   1.0         61     2490        0.199432    0.182933
#
#        emailer_for_promotion  homepage_featured  city_code  region_code  \
# ...

# %%
# Dropping the columns which is not necessary
df1_train = df1_train.drop(["id","center_id","meal_id","city_code","region_code"], axis = 1)

# %%
df1_train.head()
# Out:
#    week  checkout_price  base_price  emailer_for_promotion  homepage_featured  \
# 0   0.0        0.155056    0.119543                      0                  0
# 1   0.0        0.155056    0.099245                      0                  0
# 2   0.0        0.152774    0.099282                      0                  0
# 3   0.0        0.389818    0.471292                      0                  0
# 4   0.0        0.278617    0.230787                      0                  0
#
#    num_orders   op_area  category_encoded  cuisine_Indian  cuisine_Italian  \
# 0         177  0.180328          0.280124               0                0
# 1         270  0.180328          0.280124               0                0
# 2         189  0.180328          0.280124               0                0
# 3          54  0.180328          0.280124               1                0
# 4          40  0.180328          0.280124               1                0
#
#    cuisine_Thai  Center_TYPE_B  Center_TYPE_C
# ...

# %%
# Dropping in testing data
df1_test = df1_test.drop(["id","center_id","meal_id","city_code","region_code"], axis = 1)

# %%
df1_test.head()
# Out:
#    week  checkout_price  base_price  emailer_for_promotion  homepage_featured  \
# 0   0.0        0.086266    0.068274                      0                  0
# 1   0.0        0.088178    0.068274                      0                  0
# 2   0.0        0.085338    0.068303                      0                  0
# 3   0.0        0.090005    0.071117                      0                  0
# 4   0.0        0.091831    0.072984                      0                  0
#
#     op_area  category_encoded  cuisine_Indian  cuisine_Italian  cuisine_Thai  \
# 0  0.180328          0.272956               0                0             1
# 1  0.180328          0.272956               0                0             1
# 2  0.180328          0.272956               0                0             1
# 3  0.180328          0.272956               1                0             0
# 4  0.180328          0.272956               1                0             0
#
#    Center_TYPE_B  Center_TYPE_C
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(numerical_df.corr(),annot= True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Separate the features and labels.

# %%
y_train = df1_train["num_orders"]
X_train = df1_train.drop(["num_orders"], axis = 1)
X_test = df1_test

# %%
# Model training and evaluation

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
Linear_model = LinearRegression()
Linear_model.fit(X_train,y_train)
y_pred = Linear_model.predict(X_test)

# %%
y_pred
# Out:
# array([171.55038656, 170.76368135, 171.9162464 , ..., 428.1756275 ,
#        428.1756275 , 470.50603939])

# %%
df_result = pd.DataFrame(y_pred)
df_result
# Out:
#                 0
# 0      171.550387
# 1      170.763681
# 2      171.916246
# 3      284.091059
# 4      282.340686
# ...           ...
# 32568  224.990950
# 32569  225.120671
# 32570  428.175627
# 32571  428.175627
# 32572  470.506039
#
# [32573 rows x 1 columns]

# %%
Id = df_test["id"]
Id
# Out:
# 0        1028232
# 1        1127204
# 2        1212707
# 3        1082698
# 4        1400926
#           ...
# 32568    1250239
# 32569    1039516
# 32570    1158107
# 32571    1444235
# 32572    1291286
# Name: id, Length: 32573, dtype: int64

# %%
df1_result= pd.concat([Id,df_result],axis = 1)

# %%
df1_result
# Out:
#             id           0
# 0      1028232  171.550387
# 1      1127204  170.763681
# 2      1212707  171.916246
# 3      1082698  284.091059
# 4      1400926  282.340686
# ...        ...         ...
# 32568  1250239  224.990950
# 32569  1039516  225.120671
# 32570  1158107  428.175627
# 32571  1444235  428.175627
# 32572  1291286  470.506039
#
# [32573 rows x 2 columns]

# %%
df1_result.rename(columns={0: 'num_orders'}, inplace=True)

# %%
df1_result['num_orders'] = df1_result['num_orders'].clip(lower=0)
df1_result.to_csv("results.csv", index=False)
